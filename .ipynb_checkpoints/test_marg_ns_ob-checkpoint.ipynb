# %%
from numpy import *
from matplotlib.pyplot import *

# %matplotlib inline

# %%
base=loadtxt('base_fid_scalCovCls.dat')
ns_0p01=loadtxt('var_ns_0p01_scalCovCls.dat')
ns_0p005=loadtxt('var_ns_0p005_scalCovCls.dat')
ns_0p01_m=loadtxt('var_ns_0p01_m_scalCovCls.dat')
ns_0p005_m=loadtxt('var_ns_0p005_m_scalCovCls.dat')

def column(tr1,tr2,b1,b2,Nb):
    return 3*(3 + 2* Nb) + (tr1 - 1)* (3 + 2* Nb)* Nb + (b1 - 1)* (3 + 2 *Nb) + 3 + (tr2 - 1)* Nb + b2

l=base[:,0]

# %%
#plot(l,base[:,column(1,2,1,1,1)],'--')
plot(l,ns_0p01[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'b')
plot(l,ns_0p005[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'r')
plot(l,ns_0p01_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'b')
plot(l,ns_0p005_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'r')
plot(l,ns_0p001[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'g')
plot(l,ns_0p001_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'g')
plot(l,ns_0p002[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'k')
plot(l,ns_0p002_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'k')
plot(l,ns_0p004[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'m')
plot(l,ns_0p004_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'m')
plot(l,ns_0p0005[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'y')
plot(l,ns_0p0005_m[:,column(1,1,1,1,1)]/base[:,column(1,1,1,1,1)],'y')
xlim([30,70])
ylim([0.98,1.02])
show()

# %%
def derivcl(h,m2,m1,p1,p2):
        return (m2-8*m1+8*p1-p2)/(12.0*h)

# %%
plot(l,derivcl(0.001,ns_0p002_m,ns_0p001_m,ns_0p001,ns_0p002)[:,column(1,1,1,1,1)])
xlim([0,100])
ylim([-0.01,0.01])
show()

# %%
plot(l,derivcl(0.005,ns_0p01_m,ns_0p005_m,ns_0p005,ns_0p01)[:,column(1,1,1,1,1)])
xlim([0,100])
ylim([-0.01,0.01])
show()

# %%
ns_0p001=loadtxt('var_ns_0p001_scalCovCls.dat')
ns_0p002=loadtxt('var_ns_0p002_scalCovCls.dat')
ns_0p001_m=loadtxt('var_ns_0p001_m_scalCovCls.dat')
ns_0p002_m=loadtxt('var_ns_0p002_m_scalCovCls.dat')

# %%
plot(l,base[:,column(1,2,1,1,1)],'--')
plot(l,ns_0p001[:,column(1,2,1,1,1)],'b')
plot(l,ns_0p002[:,column(1,2,1,1,1)],'r')
plot(l,ns_0p001_m[:,column(1,2,1,1,1)],'b')
plot(l,ns_0p002_m[:,column(1,2,1,1,1)],'r')

show()

# %%
plot(l,derivcl(0.005,ns_0p01_m,ns_0p005_m,ns_0p005,ns_0p01)[:,column(1,1,1,1,1)],'b')
plot(l,derivcl(0.002,ns_0p004_m,ns_0p002_m,ns_0p002,ns_0p004)[:,column(1,1,1,1,1)],'k')
plot(l,derivcl(0.01,ns_0p02_m,ns_0p01_m,ns_0p01,ns_0p02)[:,column(1,1,1,1,1)],'r')
#plot(l,derivcl(0.001,ns_0p002_m,ns_0p001_m,ns_0p001,ns_0p002)[:,column(1,1,1,1,1)],'r')
#plot(l,derivcl(0.0005,ns_0p001_m,ns_0p0005_m,ns_0p0005,ns_0p001)[:,column(1,1,1,1,1)],'m')
xlim([40,85])
ylim([-0.009,0.0])
show()

# %%
plot(l,derivcl(0.005,ns_0p01_m,ns_0p005_m,ns_0p005,ns_0p01)[:,column(1,1,1,1,1)]/derivcl(0.01,ns_0p02_m,ns_0p01_m,ns_0p01,ns_0p02)[:,column(1,1,1,1,1)],'b')
plot(l,derivcl(0.002,ns_0p004_m,ns_0p002_m,ns_0p002,ns_0p004)[:,column(1,1,1,1,1)]/derivcl(0.01,ns_0p02_m,ns_0p01_m,ns_0p01,ns_0p02)[:,column(1,1,1,1,1)],'k')
#plot(l,derivcl(0.01,ns_0p02_m,ns_0p01_m,ns_0p01,ns_0p02)[:,column(1,1,1,1,1)],'r')

show()

# %%
ns_0p004=loadtxt('var_ns_0p004_scalCovCls.dat')
ns_0p004_m=loadtxt('var_ns_0p004_m_scalCovCls.dat')

# %%
ns_0p0005=loadtxt('var_ns_0p0005_scalCovCls.dat')
ns_0p0005_m=loadtxt('var_ns_0p0005_m_scalCovCls.dat')

# %%
ns_0p02=loadtxt('var_ns_0p02_scalCovCls.dat')
ns_0p02_m=loadtxt('var_ns_0p02_m_scalCovCls.dat')

# %%
plot(l,derivcl(0.005,ns_0p01_m,ns_0p005_m,ns_0p005,ns_0p01)[:,column(1,1,1,1,1)]/derivcl(0.002,ns_0p004_m,ns_0p002_m,ns_0p002,ns_0p004)[:,column(1,1,1,1,1)])
#xlim([0,100])
#ylim([-0.01,0.01])
show()

# %%
plot(l,derivcl(0.001,ns_0p002_m,ns_0p001_m,ns_0p001,ns_0p002)[:,column(1,1,1,1,1)]/derivcl(0.002,ns_0p004_m,ns_0p002_m,ns_0p002,ns_0p004)[:,column(1,1,1,1,1)])
#xlim([0,100])
#ylim([-0.01,0.01])
show()

# %%
plot(l,derivcl(0.0005,ns_0p001_m,ns_0p0005_m,ns_0p0005,ns_0p001)[:,column(1,1,1,1,1)],'m')
xlim([0,300])
ylim([-0.02,0.00001])
show()

# %%
ns_02=loadtxt('var_ns_02_scalCovCls.dat')
ns_02_m=loadtxt('var_ns_02_m_scalCovCls.dat')
ns_01=loadtxt('var_ns_01_scalCovCls.dat')
ns_01_m=loadtxt('var_ns_01_m_scalCovCls.dat')
ns_005=loadtxt('var_ns_005_scalCovCls.dat')
ns_005_m=loadtxt('var_ns_005_m_scalCovCls.dat')

# %%
ns_04=loadtxt('var_ns_04_scalCovCls.dat')
ns_04_m=loadtxt('var_ns_04_m_scalCovCls.dat')
ns_03=loadtxt('var_ns_03_scalCovCls.dat')
ns_03_m=loadtxt('var_ns_03_m_scalCovCls.dat')
ns_015=loadtxt('var_ns_015_scalCovCls.dat')
ns_015_m=loadtxt('var_ns_015_m_scalCovCls.dat')

# %%
plot(l,derivcl(0.005,ns_01_m,ns_005_m,ns_005,ns_01)[:,column(2,2,1,1,1)],'b')
plot(l,derivcl(0.01,ns_02_m,ns_01_m,ns_01,ns_02)[:,column(2,2,1,1,1)],'k')
plot(l,derivcl(0.02,ns_04_m,ns_02_m,ns_02,ns_04)[:,column(2,2,1,1,1)],'r')
#xlim([40,85])
#ylim([-0.009,0.0])
show()

# %%
wl_1=loadtxt('marg_1wl_scalCovCls.dat')
wl_2=loadtxt('marg_2wl_scalCovCls.dat')
gr_1=loadtxt('marg_1gr_scalCovCls.dat')
gr_2=loadtxt('marg_2gr_scalCovCls.dat')
l=wl_1[:,0]

# %%
plot(l,wl_2[:,-1])
plot(l,wl_1[:,-1])
show()

# %%
plot(l,(wl_2[:,-1]/wl_1[:,-1]-4)/4*100)
show()

# %%
plot(l,gr_2[:,-1])
plot(l,gr_1[:,-1])
show()

# %%
plot(l,(gr_2[:,-1]/gr_1[:,-1]-4)/4*100)
show()
